# %% [markdown]
# # **Data Loading**

# %%
import os
import pandas as pd

METADATA_PATH = "/content/data/Short Task for NUS/commonvoice-v24_en-AU-split.csv"
AUDIO_DIR = "/content/data/Short Task for NUS/audio_files"

# %%
df = pd.read_csv(METADATA_PATH)

print("Total samples:", len(df))
print("Columns:", df.columns.tolist())
# Out:
# Total samples: 55673
# Columns: ['Unnamed: 0', 'client_id', 'path', 'sentence_id', 'sentence', 'sentence_domain', 'up_votes', 'down_votes', 'age', 'gender', 'accents', 'variant', 'locale', 'segment', 'duration_ms']
